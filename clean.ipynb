# %%
import pandas as pd
import numpy as np
import csv

# %%
df1 = pd.read_excel('/Users/ice/Desktop/Clean Data/order_1624629348551.xlsx')
df2 = pd.read_excel('/Users/ice/Desktop/Clean Data/order_1624629360011.xlsx')
df5 = pd.read_excel('/Users/ice/Desktop/Clean Data/sku_stock_1624780047141.xlsx')
df1
# Out:
#           [order_no*] [order_date*]  [order_net*]      [status*]  \
# 0     210327S00043X43    27/03/2021          1190     จัดส่งแล้ว
# 1     210327S00044X44    27/03/2021          1190     จัดส่งแล้ว
# 2     210328U00046X46    28/03/2021          1190         ยกเลิก
# 3     210328U00047X47    28/03/2021          1190     จัดส่งแล้ว
# 4     210329M00048X48    29/03/2021          1400         ยกเลิก
# ..                ...           ...           ...            ...
# 144  210624R00141X141    24/06/2021           498     จัดส่งแล้ว
# 145  210625F00142X142    25/06/2021           360     จัดส่งแล้ว
# 146  210625F00143X143    25/06/2021           240  ที่ต้องจัดส่ง
# 147  210625F00144X144    25/06/2021           604     จัดส่งแล้ว
# 148  210625F00144X144    25/06/2021           604     จัดส่งแล้ว
#
#          [payment_time*]           [Bank*]    [payment_type*]  \
# 0    2021-03-27 20:20:00  ธนาคารไทยพาณิชย์    Direct Transfer
# ...

# %%
dfx = pd.concat([df1, df2], ignore_index=True)
dfx['date'] = pd.to_datetime(dfx['[order_date*]'],format="%d/%m/%Y")
dfx
# Out:
#          [order_no*] [order_date*]  [order_net*]            [status*]  \
# 0    210327S00043X43    27/03/2021          1190           จัดส่งแล้ว
# 1    210327S00044X44    27/03/2021          1190           จัดส่งแล้ว
# 2    210328U00046X46    28/03/2021          1190               ยกเลิก
# 3    210328U00047X47    28/03/2021          1190           จัดส่งแล้ว
# 4    210329M00048X48    29/03/2021          1400               ยกเลิก
# ..               ...           ...           ...                  ...
# 190  210326F00038X38    26/03/2021          1190           จัดส่งแล้ว
# 191  210326F00039X39    26/03/2021          1190  ลูกค้ารับสินค้าแล้ว
# 192  210326F00040X40    26/03/2021          1190           จัดส่งแล้ว
# 193  210326F00041X41    26/03/2021          1190           จัดส่งแล้ว
# 194  210327S00042X42    27/03/2021          1190           จัดส่งแล้ว
#
#          [payment_time*]           [Bank*]    [payment_type*]  \
# 0    2021-03-27 20:20:00  ธนาคารไทยพาณิชย์    Direct Transfer
# ...

# %%
with open('/Users/ice/Desktop/Clean Data/PrismStuff-21062507850bad.csv', 'r', encoding='utf-16') as file:
    read_file = csv.reader(file, delimiter='\t')
    df4 = pd.DataFrame(read_file)
    

header = df4.iloc[0]
df4 = df4[1:]
df4.columns = header
df4

df4['date'] = pd.to_datetime(df4['Paid At'])
df4['date'] = df4['date'].dt.date
df4 = df4[~df4.date.isna()]
df4
# Out:
# 0   No.                 Created At   Status                 Customer Name  \
# 1   103  2021-06-19 17:22:03 +0700  shipped                  ภูรี วงศ์วาร
# 2   103  2021-06-19 17:22:03 +0700  shipped                  ภูรี วงศ์วาร
# 3   103  2021-06-19 17:22:03 +0700  shipped                  ภูรี วงศ์วาร
# 4   104  2021-06-20 12:36:13 +0700  shipped           อินทนิลา พิพิธภัณฑ์
# 5   104  2021-06-20 12:36:13 +0700  shipped           อินทนิลา พิพิธภัณฑ์
# 6   104  2021-06-20 12:36:13 +0700  shipped           อินทนิลา พิพิธภัณฑ์
# 7   106  2021-06-21 10:19:50 +0700  shipped                        เจอรี่
# 8   106  2021-06-21 10:19:50 +0700  shipped                        เจอรี่
# 9   106  2021-06-21 10:19:50 +0700  shipped                        เจอรี่
# 10  106  2021-06-21 10:19:50 +0700  shipped                        เจอรี่
# 11  108  2021-06-21 18:40:58 +0700  shipped     Parameshvar Tangsathaporn
# 12  108  2021-06-21 18:40:58 +0700  shipped     Parameshvar Tangsathaporn
# ...

# %%
# dfx.to_csv('combine.csv',index=False)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 1 to 54
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No.               47 non-null     object
#  1   Created At        47 non-null     object
#  2   Status            47 non-null     object
#  3   Customer Name     47 non-null     object
#  4   Customer Phone    47 non-null     object
#  5   Customer Email    47 non-null     object
#  6   Customer Address  47 non-null     object
#  7   Tracking Number   47 non-null     object
#  8   Payment Provider  47 non-null     object
#  9   Account No.       47 non-null     object
#  10  Account Name      47 non-null     object
#  11  Shipping Option   47 non-null     object
#  12  Shipping Cost     47 non-null     object
#  13  Subtotal          47 non-null     object
#  14  Discount          47 non-null     object
#  15  Total             47 non-null     object
# ...

# %%
df5
# Out:
#           SKU ID            รหัสสินค้า ref SKU ID  \
# 0      210315973  COL001210315FB44EP8Z   CO104377
# 1      210315974  COL001210315FB44M09N   CO104677
# 2     2103261212  STU0012103267DVAR5J4   ST110192
# 3     2103261213  STU0012103267DVAYSNZ   ST110292
# 4     2103261214  STU0012103267DVAJLAO   ST110392
# ...          ...                   ...        ...
# 1316   210224717  POR001210224NCWSU822   PO100152
# 1317   210303757  HAP001210303TC7T5UK8   HA100372
# 1318   210208513  ROG001210208AEGEGIEM    RO10210
# 1319   210208512  ROG001210208KNBHFJGH    RO10200
# 1320   210208498  ROG001210208CJDAPPRN    RO10100
#
#                                              ชื่อสินค้า  คลัง  ราคา
# 0     SEX EDUCATION SHIRT WOMEN  Color  Green(GRN)  ...     1  2450
# 1     SEX EDUCATION SHIRT WOMEN  Color  Green(GRN)  ...     0  2450
# 2     Lovers Navy Swim Briefs  Color  Navy (ENA(stud...     2  1690
# 3     Lovers Navy Swim Briefs  Color  Navy (ENA(stud...     3  1690
# ...

# %%
dfm = df4.merge(df5, left_on = 'Item Code', right_on = 'ref SKU ID')
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No.               43 non-null     object
#  1   Created At        43 non-null     object
#  2   Status            43 non-null     object
#  3   Customer Name     43 non-null     object
#  4   Customer Phone    43 non-null     object
#  5   Customer Email    43 non-null     object
#  6   Customer Address  43 non-null     object
#  7   Tracking Number   43 non-null     object
#  8   Payment Provider  43 non-null     object
#  9   Account No.       43 non-null     object
#  10  Account Name      43 non-null     object
#  11  Shipping Option   43 non-null     object
#  12  Shipping Cost     43 non-null     object
#  13  Subtotal          43 non-null     object
#  14  Discount          43 non-null     object
#  15  Total             43 non-null     object
# ...

# %%
dfm.info()
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No.               43 non-null     object
#  1   Created At        43 non-null     object
#  2   Status            43 non-null     object
#  3   Customer Name     43 non-null     object
#  4   Customer Phone    43 non-null     object
#  5   Customer Email    43 non-null     object
#  6   Customer Address  43 non-null     object
#  7   Tracking Number   43 non-null     object
#  8   Payment Provider  43 non-null     object
#  9   Account No.       43 non-null     object
#  10  Account Name      43 non-null     object
#  11  Shipping Option   43 non-null     object
#  12  Shipping Cost     43 non-null     object
#  13  Subtotal          43 non-null     object
#  14  Discount          43 non-null     object
#  15  Total             43 non-null     object
# ...

# %%
df1_clean = dfm.drop(dfm.columns[[2, 4, 5, 7, 9, 16, 18, 19, 20, 21 ,25, 31, 32]], axis=1)
df2_clean = dfx.drop(dfx.columns[[3, 5, 6, 40, 42]], axis=1)
df1_clean
# Out:
#     No.                 Created At               Customer Name  \
# 0   103  2021-06-19 17:22:03 +0700                ภูรี วงศ์วาร
# 1   104  2021-06-20 12:36:13 +0700         อินทนิลา พิพิธภัณฑ์
# 2   109  2021-06-22 09:51:55 +0700          Koonlapong Srichan
# 3   111  2021-06-22 12:00:13 +0700                        源佐 張
# 4   129  2021-06-24 18:11:20 +0700         Pimpattra Kosalanun
# 5   130  2021-06-24 18:22:15 +0700         Pimpattra Kosalanun
# 6   103  2021-06-19 17:22:03 +0700                ภูรี วงศ์วาร
# 7   104  2021-06-20 12:36:13 +0700         อินทนิลา พิพิธภัณฑ์
# 8   106  2021-06-21 10:19:50 +0700                      เจอรี่
# 9   108  2021-06-21 18:40:58 +0700   Parameshvar Tangsathaporn
# 10  109  2021-06-22 09:51:55 +0700          Koonlapong Srichan
# 11  121  2021-06-23 12:25:17 +0700  นายเบญทวิช  สุรศาสตร์พิศาล
# 12  124  2021-06-23 18:02:35 +0700                        Mick
# 13  128  2021-06-24 18:05:51 +0700                 ธัชพล ศิลปี
# ...

# %%
df1_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No.               43 non-null     object
#  1   Created At        43 non-null     object
#  2   Customer Name     43 non-null     object
#  3   Customer Address  43 non-null     object
#  4   Payment Provider  43 non-null     object
#  5   Account Name      43 non-null     object
#  6   Shipping Option   43 non-null     object
#  7   Shipping Cost     43 non-null     object
#  8   Subtotal          43 non-null     object
#  9   Discount          43 non-null     object
#  10  Total             43 non-null     object
#  11  Paid Amount       43 non-null     object
#  12  Item Qty          43 non-null     object
#  13  Item Price        43 non-null     object
#  14  Item Subtotal     43 non-null     object
#  15  date              43 non-null     object
# ...

# %%
df2_clean
# Out:
#          [order_no*] [order_date*]  [order_net*]      [payment_time*]  \
# 0    210327S00043X43    27/03/2021          1190  2021-03-27 20:20:00
# 1    210327S00044X44    27/03/2021          1190  2021-03-27 22:29:00
# 2    210328U00046X46    28/03/2021          1190                  NaN
# 3    210328U00047X47    28/03/2021          1190  2021-03-28 18:23:00
# 4    210329M00048X48    29/03/2021          1400                  NaN
# ..               ...           ...           ...                  ...
# 190  210326F00038X38    26/03/2021          1190  2021-03-26 19:30:00
# 191  210326F00039X39    26/03/2021          1190  2021-03-26 20:53:00
# 192  210326F00040X40    26/03/2021          1190  2021-03-26 21:04:00
# 193  210326F00041X41    26/03/2021          1190  2021-03-26 21:08:00
# 194  210327S00042X42    27/03/2021          1190  2021-03-27 17:47:00
#
#                  [name*]                                         [address*]  \
# ...

# %%
df2_clean = df2_clean.drop(df2_clean.iloc[:,5:26].columns, axis=1)
df2_clean
# Out:
#          [order_no*] [order_date*]  [order_net*]      [payment_time*]  \
# 0    210327S00043X43    27/03/2021          1190  2021-03-27 20:20:00
# 1    210327S00044X44    27/03/2021          1190  2021-03-27 22:29:00
# 2    210328U00046X46    28/03/2021          1190                  NaN
# 3    210328U00047X47    28/03/2021          1190  2021-03-28 18:23:00
# 4    210329M00048X48    29/03/2021          1400                  NaN
# ..               ...           ...           ...                  ...
# 190  210326F00038X38    26/03/2021          1190  2021-03-26 19:30:00
# 191  210326F00039X39    26/03/2021          1190  2021-03-26 20:53:00
# 192  210326F00040X40    26/03/2021          1190  2021-03-26 21:04:00
# 193  210326F00041X41    26/03/2021          1190  2021-03-26 21:08:00
# 194  210327S00042X42    27/03/2021          1190  2021-03-27 17:47:00
#
#                  [name*]             [shipping_method*]  \
# 0       Yanisa Riewruja               Thailand Post-EMS
# ...

# %%
df1_clean
# Out:
#     No.                 Created At               Customer Name  \
# 0   103  2021-06-19 17:22:03 +0700                ภูรี วงศ์วาร
# 1   104  2021-06-20 12:36:13 +0700         อินทนิลา พิพิธภัณฑ์
# 2   109  2021-06-22 09:51:55 +0700          Koonlapong Srichan
# 3   111  2021-06-22 12:00:13 +0700                        源佐 張
# 4   129  2021-06-24 18:11:20 +0700         Pimpattra Kosalanun
# 5   130  2021-06-24 18:22:15 +0700         Pimpattra Kosalanun
# 6   103  2021-06-19 17:22:03 +0700                ภูรี วงศ์วาร
# 7   104  2021-06-20 12:36:13 +0700         อินทนิลา พิพิธภัณฑ์
# 8   106  2021-06-21 10:19:50 +0700                      เจอรี่
# 9   108  2021-06-21 18:40:58 +0700   Parameshvar Tangsathaporn
# 10  109  2021-06-22 09:51:55 +0700          Koonlapong Srichan
# 11  121  2021-06-23 12:25:17 +0700  นายเบญทวิช  สุรศาสตร์พิศาล
# 12  124  2021-06-23 18:02:35 +0700                        Mick
# 13  128  2021-06-24 18:05:51 +0700                 ธัชพล ศิลปี
# ...

# %%
df1_clean = df1_clean.drop(df1_clean.columns[[1, 8]], axis=1)
df2_clean = df2_clean.drop(df2_clean.columns[[2,15]], axis=1)

# %%
df1_clean.info()
df2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No.               43 non-null     object
#  1   Customer Name     43 non-null     object
#  2   Customer Address  43 non-null     object
#  3   Payment Provider  43 non-null     object
#  4   Account Name      43 non-null     object
#  5   Shipping Option   43 non-null     object
#  6   Shipping Cost     43 non-null     object
#  7   Discount          43 non-null     object
#  8   Total             43 non-null     object
#  9   Paid Amount       43 non-null     object
#  10  Item Qty          43 non-null     object
#  11  Item Price        43 non-null     object
#  12  Item Subtotal     43 non-null     object
#  13  date              43 non-null     object
#  14  SKU ID            43 non-null     int64
#  15  รหัสสินค้า        43 non-null     object
# ...

# %%
# df1_clean = df1_clean[['No.','date', '']]
# df1_clean.columns = ['order_no', 'name', 'address', 'payment', 'acname']
df1_clean = df1_clean.drop(df1_clean.columns[[3, 4]], axis=1)

# %%
df1_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No.               43 non-null     object
#  1   Customer Name     43 non-null     object
#  2   Customer Address  43 non-null     object
#  3   Shipping Option   43 non-null     object
#  4   Shipping Cost     43 non-null     object
#  5   Discount          43 non-null     object
#  6   Total             43 non-null     object
#  7   Paid Amount       43 non-null     object
#  8   Item Qty          43 non-null     object
#  9   Item Price        43 non-null     object
#  10  Item Subtotal     43 non-null     object
#  11  date              43 non-null     object
#  12  SKU ID            43 non-null     int64
#  13  รหัสสินค้า        43 non-null     object
#  14  ref SKU ID        43 non-null     object
#  15  ชื่อสินค้า        43 non-null     object
# ...

# %%
df1_clean.columns = ['order_no', 'name', 'address', 'shipping_method', 'shipping_cost', 'discount', 'total', 'paid_amount', 'quantity', 'price', 'subtotal', 'date', 'sku_iddd', 'sku_id', 'ref', 'product_name']

# %%
df1_clean = df1_clean.drop(df1_clean.columns[[6]], axis=1)

# %%
df1_clean = df1_clean.drop(df1_clean.columns[[11]], axis=1)
df1_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_no         43 non-null     object
#  1   name             43 non-null     object
#  2   address          43 non-null     object
#  3   shipping_method  43 non-null     object
#  4   shipping_cost    43 non-null     object
#  5   discount         43 non-null     object
#  6   paid_amount      43 non-null     object
#  7   quantity         43 non-null     object
#  8   price            43 non-null     object
#  9   subtotal         43 non-null     object
#  10  date             43 non-null     object
#  11  sku_id           43 non-null     object
#  12  ref              43 non-null     object
#  13  product_name     43 non-null     object
# dtypes: object(14)
# memory usage: 5.0+ KB

# %%
df1_clean
# Out:
#    order_no                        name  \
# 0       103                ภูรี วงศ์วาร
# 1       104         อินทนิลา พิพิธภัณฑ์
# 2       109          Koonlapong Srichan
# 3       111                        源佐 張
# 4       129         Pimpattra Kosalanun
# 5       130         Pimpattra Kosalanun
# 6       103                ภูรี วงศ์วาร
# 7       104         อินทนิลา พิพิธภัณฑ์
# 8       106                      เจอรี่
# 9       108   Parameshvar Tangsathaporn
# 10      109          Koonlapong Srichan
# 11      121  นายเบญทวิช  สุรศาสตร์พิศาล
# 12      124                        Mick
# 13      128                 ธัชพล ศิลปี
# 14      129         Pimpattra Kosalanun
# 15      103                ภูรี วงศ์วาร
# 16      130         Pimpattra Kosalanun
# 17      104         อินทนิลา พิพิธภัณฑ์
# 18      106                      เจอรี่
# 19      108   Parameshvar Tangsathaporn
# 20      109          Koonlapong Srichan
# 21      129         Pimpattra Kosalanun
# ...

# %%
df2_clean
# Out:
#          [order_no*] [order_date*]      [payment_time*]              [name*]  \
# 0    210327S00043X43    27/03/2021  2021-03-27 20:20:00     Yanisa Riewruja
# 1    210327S00044X44    27/03/2021  2021-03-27 22:29:00  วิกาวี วัฒนวิจารณ์
# 2    210328U00046X46    28/03/2021                  NaN        Sedthalug N.
# 3    210328U00047X47    28/03/2021  2021-03-28 18:23:00        Sedthalug N.
# 4    210329M00048X48    29/03/2021                  NaN                 Fay
# ..               ...           ...                  ...                  ...
# 190  210326F00038X38    26/03/2021  2021-03-26 19:30:00              คุณมอส
# 191  210326F00039X39    26/03/2021  2021-03-26 20:53:00   กนกนาถ  มี​พร้อม​
# 192  210326F00040X40    26/03/2021  2021-03-26 21:04:00       Rattanawadee
# 193  210326F00041X41    26/03/2021  2021-03-26 21:08:00      สุวิมล นิยมการ
# 194  210327S00042X42    27/03/2021  2021-03-27 17:47:00           Nuttakarn
#
#                 [shipping_method*]  \
# ...

# %%
df1_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_no         43 non-null     object
#  1   name             43 non-null     object
#  2   address          43 non-null     object
#  3   shipping_method  43 non-null     object
#  4   shipping_cost    43 non-null     object
#  5   discount         43 non-null     object
#  6   paid_amount      43 non-null     object
#  7   quantity         43 non-null     object
#  8   price            43 non-null     object
#  9   subtotal         43 non-null     object
#  10  date             43 non-null     object
#  11  sku_id           43 non-null     object
#  12  ref              43 non-null     object
#  13  product_name     43 non-null     object
# dtypes: object(14)
# memory usage: 5.0+ KB

# %%
df2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   [order_no*]              195 non-null    object
#  1   [order_date*]            195 non-null    object
#  2   [payment_time*]          132 non-null    object
#  3   [name*]                  195 non-null    object
#  4   [shipping_method*]       195 non-null    object
#  5   [Product Name*]          195 non-null    object
#  6   [Brand Name*]            195 non-null    object
#  7   [SKU 1 Name*]            189 non-null    object
#  8   [quantity*]              195 non-null    int64
#  9   [NormalPrice*]           195 non-null    int64
#  10  [Price*]                 195 non-null    int64
#  11  [totalPrice*]            195 non-null    int64
#  12  [Ship Cost*]             195 non-null    int64
#  13  [Discount*]              195 non-null    float64
# ...

# %%
# df2_clean = df2_clean.drop(df2_clean.columns[[2, 6,]], axis=1)
df2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   [order_no*]              195 non-null    object
#  1   [order_date*]            195 non-null    object
#  2   [payment_time*]          132 non-null    object
#  3   [name*]                  195 non-null    object
#  4   [shipping_method*]       195 non-null    object
#  5   [Product Name*]          195 non-null    object
#  6   [Brand Name*]            195 non-null    object
#  7   [SKU 1 Name*]            189 non-null    object
#  8   [quantity*]              195 non-null    int64
#  9   [NormalPrice*]           195 non-null    int64
#  10  [Price*]                 195 non-null    int64
#  11  [totalPrice*]            195 non-null    int64
#  12  [Ship Cost*]             195 non-null    int64
#  13  [Discount*]              195 non-null    float64
# ...

# %%
df2_clean = df2_clean.drop(df2_clean.columns[[1]], axis=1)

# %%
df2_clean = df2_clean.drop(df2_clean.columns[[1,5]], axis=1)

df2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   [order_no*]              195 non-null    object
#  1   [name*]                  195 non-null    object
#  2   [shipping_method*]       195 non-null    object
#  3   [Product Name*]          195 non-null    object
#  4   [SKU 1 Name*]            189 non-null    object
#  5   [quantity*]              195 non-null    int64
#  6   [NormalPrice*]           195 non-null    int64
#  7   [Price*]                 195 non-null    int64
#  8   [totalPrice*]            195 non-null    int64
#  9   [Ship Cost*]             195 non-null    int64
#  10  [Discount*]              195 non-null    float64
#  11  [Full ShippingAddress*]  195 non-null    object
#  12  date                     195 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(5), object(6)
# ...

# %%
df2_clean.columns = ['order_no', 'name', 'shipping_method', 'product_name', 'sku_id', 'quantity', 'paid_amount', 'price', 'total', 'shipping_cost', 'discount', 'address', 'date']

# %%
df2_clean
# Out:
#             order_no                 name                shipping_method  \
# 0    210327S00043X43     Yanisa Riewruja               Thailand Post-EMS
# 1    210327S00044X44  วิกาวี วัฒนวิจารณ์                   Kerry Express
# 2    210328U00046X46        Sedthalug N.                   Kerry Express
# 3    210328U00047X47        Sedthalug N.   Thailand Post-Registered Mail
# 4    210329M00048X48                 Fay                   Kerry Express
# ..               ...                  ...                            ...
# 190  210326F00038X38              คุณมอส   Thailand Post-Registered Mail
# 191  210326F00039X39   กนกนาถ  มี​พร้อม​                   Kerry Express
# 192  210326F00040X40       Rattanawadee                    Kerry Express
# 193  210326F00041X41      สุวิมล นิยมการ                   Kerry Express
# 194  210327S00042X42           Nuttakarn   Thailand Post-Registered Mail
#
#                                           product_name                sku_id  \
# ...

# %%
df1_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_no         43 non-null     object
#  1   name             43 non-null     object
#  2   address          43 non-null     object
#  3   shipping_method  43 non-null     object
#  4   shipping_cost    43 non-null     object
#  5   discount         43 non-null     object
#  6   paid_amount      43 non-null     object
#  7   quantity         43 non-null     object
#  8   price            43 non-null     object
#  9   subtotal         43 non-null     object
#  10  date             43 non-null     object
#  11  sku_id           43 non-null     object
#  12  ref              43 non-null     object
#  13  product_name     43 non-null     object
# dtypes: object(14)
# memory usage: 5.0+ KB

# %%
df1_clean = df1_clean.drop(df1_clean.columns[[12]], axis=1)

# %%
df1_clean['shipping_method'] = df1_clean['shipping_method'].apply(lambda x : 'Kerry Express' if x == 'Kerry' else x)
df1_clean['shipping_method'] = df1_clean['shipping_method'].apply(lambda x : 'Thailand Post-Registered Mail' if x == 'ไปรษณีย์ไทย ลงทะเบียน' else x)

# %%
df1_clean
# Out:
#    order_no                        name  \
# 0       103                ภูรี วงศ์วาร
# 1       104         อินทนิลา พิพิธภัณฑ์
# 2       109          Koonlapong Srichan
# 3       111                        源佐 張
# 4       129         Pimpattra Kosalanun
# 5       130         Pimpattra Kosalanun
# 6       103                ภูรี วงศ์วาร
# 7       104         อินทนิลา พิพิธภัณฑ์
# 8       106                      เจอรี่
# 9       108   Parameshvar Tangsathaporn
# 10      109          Koonlapong Srichan
# 11      121  นายเบญทวิช  สุรศาสตร์พิศาล
# 12      124                        Mick
# 13      128                 ธัชพล ศิลปี
# 14      129         Pimpattra Kosalanun
# 15      103                ภูรี วงศ์วาร
# 16      130         Pimpattra Kosalanun
# 17      104         อินทนิลา พิพิธภัณฑ์
# 18      106                      เจอรี่
# 19      108   Parameshvar Tangsathaporn
# 20      109          Koonlapong Srichan
# 21      129         Pimpattra Kosalanun
# ...

# %%
df2_clean = df2_clean.rename(columns={'total' : 'subtotal'})

# %%
df2_clean.info()
df1_clean.info()
a_list = df1_clean.columns.to_list()
a_list
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_no         195 non-null    object
#  1   name             195 non-null    object
#  2   shipping_method  195 non-null    object
#  3   product_name     195 non-null    object
#  4   sku_id           189 non-null    object
#  5   quantity         195 non-null    int64
#  6   paid_amount      195 non-null    int64
#  7   price            195 non-null    int64
#  8   subtotal         195 non-null    int64
#  9   shipping_cost    195 non-null    int64
#  10  discount         195 non-null    float64
#  11  address          195 non-null    object
#  12  date             195 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(5), object(6)
# memory usage: 19.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# ...

# %%
df2_clean = df2_clean[a_list]

# %%
df2_clean.head()
# Out:
#           order_no                 name  \
# 0  210327S00043X43     Yanisa Riewruja
# 1  210327S00044X44  วิกาวี วัฒนวิจารณ์
# 2  210328U00046X46        Sedthalug N.
# 3  210328U00047X47        Sedthalug N.
# 4  210329M00048X48                 Fay
#
#                                              address  \
# 0  เลขที่ 16/16 สุขุมวิท 19 แขวง คลองเตยเหนือ เขต...
# 1  เลขที่ 9/387 พลัมคอนโดปิ่นเกล้าสเตชั่น ถ.สมเด็...
# 2  เลขที่ 70 ซอยเสนานิคม 1 ซอย 42 แยก 11 (ซอย 8/6...
# 3  เลขที่ 70 ซอยเสนานิคม 1 ซอย 42 แยก 11 (ซอย 8/6...
# 4  เลขที่ 441/34 boromtai ต.ในเมือง อ.เมืองพิษณุโ...
#
#                  shipping_method  shipping_cost  discount  paid_amount  \
# 0              Thailand Post-EMS             60       0.0         1190
# 1                  Kerry Express             60       0.0         1190
# 2                  Kerry Express             60       0.0         1190
# 3  Thailand Post-Registered Mail             40       0.0         1190
# ...

# %%
df2_clean['date'] = pd.to_datetime(df2_clean['date'])
df2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_no         195 non-null    object
#  1   name             195 non-null    object
#  2   address          195 non-null    object
#  3   shipping_method  195 non-null    object
#  4   shipping_cost    195 non-null    int64
#  5   discount         195 non-null    float64
#  6   paid_amount      195 non-null    int64
#  7   quantity         195 non-null    int64
#  8   price            195 non-null    int64
#  9   subtotal         195 non-null    int64
#  10  date             195 non-null    datetime64[ns]
#  11  sku_id           189 non-null    object
#  12  product_name     195 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(6)
# memory usage: 19.9+ KB

# %%
df1_clean['date'] = pd.to_datetime(df1_clean['date'])
df1_clean
# Out:
#    order_no                        name  \
# 0       103                ภูรี วงศ์วาร
# 1       104         อินทนิลา พิพิธภัณฑ์
# 2       109          Koonlapong Srichan
# 3       111                        源佐 張
# 4       129         Pimpattra Kosalanun
# 5       130         Pimpattra Kosalanun
# 6       103                ภูรี วงศ์วาร
# 7       104         อินทนิลา พิพิธภัณฑ์
# 8       106                      เจอรี่
# 9       108   Parameshvar Tangsathaporn
# 10      109          Koonlapong Srichan
# 11      121  นายเบญทวิช  สุรศาสตร์พิศาล
# 12      124                        Mick
# 13      128                 ธัชพล ศิลปี
# 14      129         Pimpattra Kosalanun
# 15      103                ภูรี วงศ์วาร
# 16      130         Pimpattra Kosalanun
# 17      104         อินทนิลา พิพิธภัณฑ์
# 18      106                      เจอรี่
# 19      108   Parameshvar Tangsathaporn
# 20      109          Koonlapong Srichan
# 21      129         Pimpattra Kosalanun
# ...

# %%
dfcomb = pd.concat([df2_clean,df1_clean], ignore_index=True)
dfcomb
# Out:
#             order_no                 name  \
# 0    210327S00043X43     Yanisa Riewruja
# 1    210327S00044X44  วิกาวี วัฒนวิจารณ์
# 2    210328U00046X46        Sedthalug N.
# 3    210328U00047X47        Sedthalug N.
# 4    210329M00048X48                 Fay
# ..               ...                  ...
# 233              114          บุ๋ม ปนัดดา
# 234              115        Moyotaro Bebe
# 235              118          บุ๋ม ปนัดดา
# 236              118          บุ๋ม ปนัดดา
# 237              120      คุณวิศวัส คันธา
#
#                                                address  \
# 0    เลขที่ 16/16 สุขุมวิท 19 แขวง คลองเตยเหนือ เขต...
# 1    เลขที่ 9/387 พลัมคอนโดปิ่นเกล้าสเตชั่น ถ.สมเด็...
# 2    เลขที่ 70 ซอยเสนานิคม 1 ซอย 42 แยก 11 (ซอย 8/6...
# 3    เลขที่ 70 ซอยเสนานิคม 1 ซอย 42 แยก 11 (ซอย 8/6...
# 4    เลขที่ 441/34 boromtai ต.ในเมือง อ.เมืองพิษณุโ...
# ..                                                 ...
# 233
# 234  ภริตา (เคท) , 0894898881\nเลขที่ 33/55 สาทรพลั...
# ...

# %%
dfcomb['date'] = pd.to_datetime(dfcomb['date'])
dfcomb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_no         238 non-null    object
#  1   name             238 non-null    object
#  2   address          238 non-null    object
#  3   shipping_method  238 non-null    object
#  4   shipping_cost    238 non-null    object
#  5   discount         238 non-null    object
#  6   paid_amount      238 non-null    object
#  7   quantity         238 non-null    object
#  8   price            238 non-null    object
#  9   subtotal         238 non-null    object
#  10  date             238 non-null    datetime64[ns]
#  11  sku_id           232 non-null    object
#  12  product_name     238 non-null    object
# dtypes: datetime64[ns](1), object(12)
# memory usage: 24.3+ KB

# %%
dfcomb.dropna(subset=['sku_id'])
# dfcomb['spu_id'] = dfcomb['sku_id'].apply(lambda x: x[:-4])
# Out:
#             order_no                 name  \
# 0    210327S00043X43     Yanisa Riewruja
# 1    210327S00044X44  วิกาวี วัฒนวิจารณ์
# 2    210328U00046X46        Sedthalug N.
# 3    210328U00047X47        Sedthalug N.
# 4    210329M00048X48                 Fay
# ..               ...                  ...
# 233              114          บุ๋ม ปนัดดา
# 234              115        Moyotaro Bebe
# 235              118          บุ๋ม ปนัดดา
# 236              118          บุ๋ม ปนัดดา
# 237              120      คุณวิศวัส คันธา
#
#                                                address  \
# 0    เลขที่ 16/16 สุขุมวิท 19 แขวง คลองเตยเหนือ เขต...
# 1    เลขที่ 9/387 พลัมคอนโดปิ่นเกล้าสเตชั่น ถ.สมเด็...
# 2    เลขที่ 70 ซอยเสนานิคม 1 ซอย 42 แยก 11 (ซอย 8/6...
# 3    เลขที่ 70 ซอยเสนานิคม 1 ซอย 42 แยก 11 (ซอย 8/6...
# 4    เลขที่ 441/34 boromtai ต.ในเมือง อ.เมืองพิษณุโ...
# ..                                                 ...
# 233
# 234  ภริตา (เคท) , 0894898881\nเลขที่ 33/55 สาทรพลั...
# ...

# %%
dfcomb = dfcomb.sort_values(['date', 'order_no']).reset_index(drop=True)

# %%
dfcomb.to_csv('dfcomb.csv', index=False)
